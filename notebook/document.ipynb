# %%
from langchain_core.documents import Document

# %%
'''doc = Document(
    page_content = "this is the main text content", 
    metadata = {
        "source" : "example.txt",
        "pages": 1, 
        "author" : "Anudeep Manda" 
         
    }
)

'''

# %%
# create a simple txt file

import os 
os.makedirs("data/text_files", exist_ok=True)

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/test.txt")

data = loader.load()

data
# Out:
# [Document(metadata={'source': '../data/text_files/test.txt'}, page_content='this is test about whether the text load from langchain works ')]

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/hello.pdf", encoding = 'utf-8')

data = loader.load()

data
# Out:
# [Document(metadata={'source': '../data/text_files/hello.pdf'}, page_content='this is pdf\n')]

# %%
# %pip install tqdm
# Out:
# /Users/anudeepmanda/Resuem_Finder_RAG_Pipeline/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pymupdf
# Out:
# /Users/anudeepmanda/Resuem_Finder_RAG_Pipeline/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import TextLoader

dir_loader = DirectoryLoader(
"../data/pdf",
glob = "**/*.pdf", # Pattern to match files
loader_cls = PyMuPDFLoader, #loader class
#loader_kwargs = {'encoding': 'utf-8'}, 
show_progress= False
)
documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'producer': 'macOS Version 15.6 (Build 24G84) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20260116012304Z00'00'", 'source': '../data/pdf/anudeep_manda_openai_coverletter.pdf', 'file_path': '../data/pdf/anudeep_manda_openai_coverletter.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': 'anudeep_dropbox_coverletter', 'author': 'Anudeep Manda', 'subject': '', 'keywords': '', 'moddate': "D:20260116012304Z00'00'", 'trapped': '', 'modDate': "D:20260116012304Z00'00'", 'creationDate': "D:20260116012304Z00'00'", 'page': 0}, page_content='Anudeep Manda \nmanda1@purdue.edu | (925) 683-7968 | linkedin.com/in/anudeepmanda \nDear OpenAI Applied Engineering Team, \nI am writing to express my strong interest in the Software Engineering Intern (Emerging Talent) \nrole on the Applied Engineering team at OpenAI. I am a Computer Engineering and Applied \nMathematics student at Purdue University, and I am deeply motivated by OpenAI’s mission to \nresponsibly deploy AI systems that are useful, reliable, and accessible to millions of users \nworldwide. OpenAI’s emphasis on learning from real-world deployment and building high-\nquality, user-centered AI products strongly aligns with how I approach engineering. \nIn my recent role as a Software Engineering Intern at USG Manufacturing, I owned the \ndevelopment of high-throughput backend services and real-time analytics pipelines processing \nover 60 RTSP camera feeds under strict latency and reliability constraints. I built backend APIs \nin Python and SQL, developed React-based dashboards for operational visibility, and deployed \ncontainerized GPU-backed inference services using Docker and CI/CD pipelines. This work \nrequired careful reasoning about system performance, correctness, and production reliability—\nskills directly applicable to building and scaling customer-facing AI products at OpenAI. \nPreviously, at an early-stage AI startup, I designed and productionized backend services using \nPython and TypeScript to support AI-powered, customer-facing features. I worked across the full \nstack, integrating React-based UIs with backend services and databases, transforming \nunstructured data into structured, queryable formats for downstream analytics and AI workflows. \nI regularly profiled latency, handled failure modes, and iterated quickly based on user \nfeedback—experience that mirrors the fast-paced, iterative environment of OpenAI’s Applied \nteams. \nBeyond my internships, my projects reflect a strong interest in applied AI systems and product \nengineering. These include a Cloudflare-inspired bot detection proxy focused on high-throughput \nrequest ingestion, observability, and secure APIs, as well as a domain-specific language model \nfor interpreting California Tax Code queries, where correctness, edge-case handling, and safe \nuser-facing behavior were critical. Across my work, I prioritize building systems that are robust, \nmeasurable, and designed to improve with real-world usage. \nI am particularly excited about the opportunity to contribute to OpenAI’s efforts to bring AI \nsafely and responsibly into real-world products like ChatGPT and the OpenAI API. I would be \nthrilled to work alongside engineers, researchers, and product teams to build scalable, user-\nfocused AI experiences that have a meaningful global impact. Thank you for your time and \nconsideration—I would welcome the opportunity to further discuss how my background and \ninterests align with OpenAI’s Applied Engineering team. \nSincerely, \nAnudeep Manda')]

# %%
type(documents[0])
# Out:
# langchain_core.documents.base.Document
